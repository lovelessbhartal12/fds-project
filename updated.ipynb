# %%
#To read the data 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
data=pd.read_csv('fraud_oracle.csv')
data.head()
# Out:
#   Month  WeekOfMonth  DayOfWeek    Make AccidentArea DayOfWeekClaimed  \
# 0   Dec            5  Wednesday   Honda        Urban          Tuesday
# 1   Jan            3  Wednesday   Honda        Urban           Monday
# 2   Oct            5     Friday   Honda        Urban         Thursday
# 3   Jun            2   Saturday  Toyota        Rural           Friday
# 4   Jan            5     Monday   Honda        Urban          Tuesday
#
#   MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus  ...  AgeOfVehicle  \
# 0          Jan                   1  Female        Single  ...       3 years
# 1          Jan                   4    Male        Single  ...       6 years
# 2          Nov                   2    Male       Married  ...       7 years
# 3          Jul                   1    Male       Married  ...   more than 7
# 4          Feb                   2  Female        Single  ...       5 years
#
#   AgeOfPolicyHolder PoliceReportFiled WitnessPresent AgentType  \
# ...

# %%
#To know the shape of data
data.shape
# Out:
# (15420, 33)

# %%
#to check the total null values in the data
data.isnull().sum()
# Out:
# Month                   0
# WeekOfMonth             0
# DayOfWeek               0
# Make                    0
# AccidentArea            0
# DayOfWeekClaimed        0
# MonthClaimed            0
# WeekOfMonthClaimed      0
# Sex                     0
# MaritalStatus           0
# Age                     0
# Fault                   0
# PolicyType              0
# VehicleCategory         0
# VehiclePrice            0
# FraudFound_P            0
# PolicyNumber            0
# RepNumber               0
# Deductible              0
# DriverRating            0
# Days_Policy_Accident    0
# Days_Policy_Claim       0
# PastNumberOfClaims      0
# AgeOfVehicle            0
# AgeOfPolicyHolder       0
# PoliceReportFiled       0
# WitnessPresent          0
# AgentType               0
# NumberOfSuppliments     0
# AddressChange_Claim     0
# NumberOfCars            0
# Year                    0
# BasePolicy              0
# dtype: int64

# %%
#To know the mean,max,wuartiles or simply the summary statistics
summary_stats= data.describe()
summary_stats
# Out:
#         WeekOfMonth  WeekOfMonthClaimed           Age  FraudFound_P  \
# count  15420.000000        15420.000000  15420.000000  15420.000000
# mean       2.788586            2.693969     39.855707      0.059857
# std        1.287585            1.259115     13.492377      0.237230
# min        1.000000            1.000000      0.000000      0.000000
# 25%        2.000000            2.000000     31.000000      0.000000
# 50%        3.000000            3.000000     38.000000      0.000000
# 75%        4.000000            4.000000     48.000000      0.000000
# max        5.000000            5.000000     80.000000      1.000000
#
#        PolicyNumber     RepNumber    Deductible  DriverRating          Year
# count  15420.000000  15420.000000  15420.000000  15420.000000  15420.000000
# mean    7710.500000      8.483268    407.704280      2.487808   1994.866472
# std     4451.514911      4.599948     43.950998      1.119453      0.803313
# ...

# %%
#To represt the summary statistics in bar chart
selected_stats = summary_stats.loc[['mean', 'max', '25%', '50%', '75%']]

selected_stats.plot(kind='bar', figsize=(10, 6), legend=True)

plt.title('Summary Statistics: Mean, Max, and Quartiles')
plt.xlabel('Statistics')
plt.ylabel('Values')

plt.xticks(rotation=45)
plt.show()

# %%
#To print the information of type of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15420 entries, 0 to 15419
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Month                 15420 non-null  object
#  1   WeekOfMonth           15420 non-null  int64
#  2   DayOfWeek             15420 non-null  object
#  3   Make                  15420 non-null  object
#  4   AccidentArea          15420 non-null  object
#  5   DayOfWeekClaimed      15420 non-null  object
#  6   MonthClaimed          15420 non-null  object
#  7   WeekOfMonthClaimed    15420 non-null  int64
#  8   Sex                   15420 non-null  object
#  9   MaritalStatus         15420 non-null  object
#  10  Age                   15420 non-null  int64
#  11  Fault                 15420 non-null  object
#  12  PolicyType            15420 non-null  object
#  13  VehicleCategory       15420 non-null  object
#  14  VehiclePrice          15420 non-null  object
# ...

# %%
#To convert the object data type into label encoded value
from sklearn.preprocessing import LabelEncoder,StandardScaler
le=LabelEncoder()
for i in data.columns:
  if data[i].dtype=='object':
    data[i]=le.fit_transform(data[i])

# %%
#To print how the data looks after label encoding
data.head()
# Out:
#    Month  WeekOfMonth  DayOfWeek  Make  AccidentArea  DayOfWeekClaimed  \
# 0      2            5          6     6             1                 6
# 1      4            3          6     6             1                 2
# 2     10            5          0     6             1                 5
# 3      6            2          2    17             0                 1
# 4      4            5          1     6             1                 6
#
#    MonthClaimed  WeekOfMonthClaimed  Sex  MaritalStatus  ...  AgeOfVehicle  \
# 0             5                   1    0              2  ...             1
# 1             5                   4    1              2  ...             4
# 2            10                   2    1              1  ...             5
# 3             6                   1    1              1  ...             6
# 4             4                   2    0              2  ...             3
#
#    AgeOfPolicyHolder  PoliceReportFiled  WitnessPresent  AgentType  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Selecting numeric features
numeric_features = data.select_dtypes(include=['number']).columns

# Setting up the figure
plt.figure(figsize=(12, 8))

# Loop through numeric features (limiting to first 4 for clarity)
for i, col in enumerate(numeric_features[:4], 1):  
    plt.subplot(2, 2, i)  # Creating 2x2 grid
    sns.boxplot(y=data[col], palette='coolwarm')
    plt.title(f'Boxplot of {col}')
    plt.ylabel(col)

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9956\771738957.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=data[col], palette='coolwarm')
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9956\771738957.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=data[col], palette='coolwarm')
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9956\771738957.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=data[col], palette='coolwarm')
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9956\771738957.py:13: FutureWarning:
#
# ...

# %%
#to count the values of data which are claimed fraud 
print(data['FraudFound_P'].value_counts())

#check the target fraudfound if it is balanced or not
plt.figure(figsize=(6, 4))
sns.countplot(x='FraudFound_P', data=data)
plt.title('Distribution of FraudFound_P')
plt.xlabel('Fraud Found (0: No, 1: Yes)')
plt.ylabel('Count')
plt.show()
# Out:
# FraudFound_P
# 0    14497
# 1      923
# Name: count, dtype: int64

# %%
#Resampling the data because there are very less count of positive fraud claim
from sklearn.utils import resample

# Separate the majority and minority classes
df_majority = data[data['FraudFound_P'] == 0]
df_minority = data[data['FraudFound_P'] == 1]

# Resample the minority class
df_minority_upsampled = resample(df_minority, replace=True, n_samples=24390, random_state=0)

# Combine the majority class with the upsampled minority class
df_resampled = pd.concat([df_majority, df_minority_upsampled])

# Check the new class distribution
print(df_resampled['FraudFound_P'].value_counts())
# Out:
# FraudFound_P
# 1    24390
# 0    14497
# Name: count, dtype: int64

# %%
#To separate dependent and independent variables
y=df_resampled['FraudFound_P']
x=df_resampled.drop('FraudFound_P',axis=1)

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x_scaled=scale.fit_transform(x)
x_scaled
# Out:
# array([[-1.01800311,  1.7529939 ,  1.56020268, ...,  4.70302312,
#         -1.02360019,  1.78594228],
#        [-0.4309581 ,  0.1938906 ,  1.56020268, ..., -0.26982567,
#         -1.02360019,  0.36778624],
#        [ 1.33017695,  1.7529939 , -1.39142066, ..., -0.26982567,
#         -1.02360019,  0.36778624],
#        ...,
#        [-0.4309581 , -0.58566106,  1.56020268, ..., -0.26982567,
#          0.22729515, -1.0503698 ],
#        [ 1.62369946, -0.58566106,  1.06826546, ...,  4.70302312,
#          1.47819049,  0.36778624],
#        [ 1.62369946,  0.1938906 ,  1.56020268, ..., -0.26982567,
#          1.47819049,  0.36778624]])

# %%
#To perform Principle component analysis for dimensionality reduction
from sklearn.decomposition import PCA
pca=PCA(n_components=10);
x_pca=pca.fit_transform(x_scaled)

# %%
x_pca.shape
# Out:
# (38887, 10)

# %%
# To separate training and testing dataset
from sklearn.model_selection import train_test_split,GridSearchCV
x_train,x_test,y_train,y_test=train_test_split(x_pca,y,test_size=0.2,random_state=42)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((31109, 10), (7778, 10), (31109,), (7778,))

# %%
#Train the model using KNN classifier
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
y_pred=knn.predict(x_test)
print(accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
# 0.9380303419902288
# [[2437  482]
#  [   0 4859]]

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)
print(accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
# 0.9757006942658781
# [[2730  189]
#  [   0 4859]]

# %%
from sklearn.ensemble import RandomForestClassifier
param = {
    'n_estimators': 200,
    'max_depth': 20,
    'min_samples_split': 5,
    'min_samples_leaf': 2,
    'random_state': 0}
rf=RandomForestClassifier(**param)
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9710722550784263

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[2694,    0],
#        [ 225, 4859]], dtype=int64)

# %%
from sklearn.svm import SVC
svm=SVC(kernel='rbf', C=1, gamma=0.1)
svm.fit(x_train,y_train)
y_pred=svm.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8671895088711751

# %%
# !pip install xgboost

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
xgb = XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=3)

# Train the mode
xgb.fit(x_train, y_train)

# Make predictions
y_pred = xgb.predict(x_test)

# Print accuracy
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8140910259706865

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Initialize the Logistic Regression classifier
log_reg = LogisticRegression(max_iter=1000)

# Train the model
log_reg.fit(x_train, y_train)

# Make predictions
y_pred = log_reg.predict(x_test)

# Print accuracy
print(accuracy_score(y_test, y_pred))
# Out:
# 0.7130367703779892

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


# Define models
models = {
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(**param),
    "SVM": SVC(kernel='rbf', C=1, gamma=0.1),
    "XGBoost": XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=3),
    "KNN": KNeighborsClassifier(n_neighbors=5),  # KNN model added
    "Logistic Regression": LogisticRegression(max_iter=1000)  # Logistic Regression added
}

# Train and evaluate models
results = []

for name, model in models.items():
    model.fit(x_train, y_train)
    y_pred_train = model.predict(x_train)  # Training accuracy
    y_pred_test = model.predict(x_test)    # Testing accuracy
    
    train_acc = accuracy_score(y_train, y_pred_train)
    test_acc = accuracy_score(y_test, y_pred_test)
    
    precision = precision_score(y_test, y_pred_test, average='weighted', zero_division=1)
    recall = recall_score(y_test, y_pred_test, average='weighted', zero_division=1)
    f1 = f1_score(y_test, y_pred_test, average='weighted', zero_division=1)

    results.append({
        "Model": name,
        "Train Accuracy": train_acc,
        "Test Accuracy": test_acc,
        "Precision": precision,
        "Recall": recall,
        "F1 Score": f1
    })

# Convert results into a DataFrame
df_results = pd.DataFrame(results)

# Print table
print(df_results)
# Out:
#                  Model  Train Accuracy  Test Accuracy  Precision    Recall  \
# 0        Decision Tree        1.000000       0.976344   0.977207  0.976344
# 1        Random Forest        0.990582       0.971072   0.972352  0.971072
# 2                  SVM        0.873477       0.867190   0.881850  0.867190
# 3              XGBoost        0.823459       0.814091   0.822520  0.814091
# 4                  KNN        0.957536       0.938030   0.943623  0.938030
# 5  Logistic Regression        0.719277       0.713037   0.707813  0.713037
#
#    F1 Score
# 0  0.976178
# 1  0.970820
# 2  0.860907
# 3  0.804828
# 4  0.936706
# 5  0.695612

# %%
import seaborn as sns
import matplotlib.pyplot as plt


df_metrics = df_results.set_index('Model')[['Train Accuracy', 'Test Accuracy', 'Precision', 'Recall', 'F1 Score']]

plt.figure(figsize=(10, 6))
sns.heatmap(df_metrics, annot=True, cmap="coolwarm", fmt=".4f", linewidths=0.5, linecolor='black')

plt.title("Model Performance Heatmap")
plt.xlabel("Metrics")
plt.ylabel("Models")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(style="whitegrid")


plt.figure(figsize=(10, 6))
df_results[['Model', 'Train Accuracy', 'Test Accuracy']].set_index('Model').plot(kind='bar', width=0.8)
plt.title("Train vs Test Accuracy for Each Model")
plt.ylabel('Accuracy')
plt.xticks(rotation=45)
plt.show()


metrics = ['Precision', 'Recall', 'F1 Score']
df_results_melted = df_results.melt(id_vars=['Model'], value_vars=metrics, var_name='Metric', value_name='Score')

plt.figure(figsize=(10, 6))
sns.barplot(x='Model', y='Score', hue='Metric', data=df_results_melted)
plt.title("Model Performance Metrics (Precision, Recall, F1 Score)")
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.legend(title='Metrics', loc='upper left')
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Initialize a list to store evaluation metrics
metrics_results = []

# Compute metrics for each model
for name, model in models.items():
    y_pred_test = model.predict(x_test)

    mse = mean_squared_error(y_test, y_pred_test)
    mae = mean_absolute_error(y_test, y_pred_test)
    r2 = r2_score(y_test, y_pred_test)

    metrics_results.append({
        "Model": name,
        "MSE": mse,
        "MAE": mae,
        "R2 Score": r2
    })

# Convert results into a DataFrame
df_metrics = pd.DataFrame(metrics_results)

# Print table
print(df_metrics)
# Out:
#                  Model       MSE       MAE  R2 Score
# 0        Decision Tree  0.023656  0.023656  0.899097
# 1        Random Forest  0.028928  0.028928  0.876613
# 2                  SVM  0.132810  0.132810  0.433516
# 3              XGBoost  0.185909  0.185909  0.207033
# 4                  KNN  0.061970  0.061970  0.735678
# 5  Logistic Regression  0.286963  0.286963 -0.223999

# %%
best_model_mse = df_metrics.loc[df_metrics["MSE"].idxmin()]["Model"]
best_model_mae = df_metrics.loc[df_metrics["MAE"].idxmin()]["Model"]
best_model_r2 = df_metrics.loc[df_metrics["R2 Score"].idxmax()]["Model"]
# Print best models based on metrics
print(f"\nModel with Lowest MSE: {best_model_mse}")
print(f"Model with Lowest MAE: {best_model_mae}")
print(f"Model with Highest R² Score: {best_model_r2}")
# Out:
# Model with Lowest MSE: Decision Tree
# Model with Lowest MAE: Decision Tree
# Model with Highest R² Score: Decision Tree

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Identify the best models based on different metrics
best_model_mse = df_metrics.loc[df_metrics["MSE"].idxmin()]["Model"]
best_model_mae = df_metrics.loc[df_metrics["MAE"].idxmin()]["Model"]
best_model_r2 = df_metrics.loc[df_metrics["R2 Score"].idxmax()]["Model"]

# Count occurrences of each model being the best
best_models = [best_model_mse, best_model_mae, best_model_r2]
best_model_counts = pd.Series(best_models).value_counts()


plt.pie(best_model_counts, labels=best_model_counts.index, autopct='%1.1f%%')

# Title
plt.title("Best Model Distribution")

# Show the chart
plt.show()

# %%
# Create a DataFrame with min and max values
min_max_table = pd.DataFrame({"Minimum Value": x.min(), "Maximum Value": x.max()})

# Print the table
print("Feature-wise Minimum and Maximum Values:")
min_max_table
# Out:
# Feature-wise Minimum and Maximum Values:
#                       Minimum Value  Maximum Value
# Month                             0             11
# WeekOfMonth                       1              5
# DayOfWeek                         0              6
# Make                              0             18
# AccidentArea                      0              1
# DayOfWeekClaimed                  0              7
# MonthClaimed                      0             12
# WeekOfMonthClaimed                1              5
# Sex                               0              1
# MaritalStatus                     0              3
# Age                               0             80
# Fault                             0              1
# PolicyType                        0              8
# VehicleCategory                   0              2
# VehiclePrice                      0              5
# PolicyNumber                      1          15420
# RepNumber                         1             16
# ...

# %%
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)  # Prevent line wrapping

# Filter data where FraudFound_P is 1
fraudulent_data = data[data['FraudFound_P'] == 1]

# Display all columns of the filtered data
print("All records where FraudFound_P is 1:")
fraudulent_data.head()
# Out:
# All records where FraudFound_P is 1:
#     Month  WeekOfMonth  DayOfWeek  Make  AccidentArea  DayOfWeekClaimed  MonthClaimed  WeekOfMonthClaimed  Sex  MaritalStatus  Age  Fault  PolicyType  VehicleCategory  VehiclePrice  FraudFound_P  PolicyNumber  RepNumber  Deductible  DriverRating  Days_Policy_Accident  Days_Policy_Claim  PastNumberOfClaims  AgeOfVehicle  AgeOfPolicyHolder  PoliceReportFiled  WitnessPresent  AgentType  NumberOfSuppliments  AddressChange_Claim  NumberOfCars  Year  BasePolicy
# 28      5            1          2     6             1                 6            12                   4    1              2    0      0           0                0             5             1            29          9         400             1                     3                  2                   3             7                  0                  0               0          0                    3                    3             0  1994           0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ensure all columns are displayed in the output
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)  # Prevent line wrappin

fraud_counts = data['FraudFound_P'].value_counts()

labels = ['Non-Fraudulent', 'Fraudulent']
colors = ['lightblue', 'salmon']
plt.figure(figsize=(6, 6))
plt.pie(fraud_counts, labels=labels, autopct='%1.1f%%', colors=colors, startangle=140, shadow=True, explode=[0, 0.1])


plt.title("Distribution of Fraudulent vs Non-Fraudulent Claims")

plt.show()

# %%
import numpy as np
import pandas as pd


def predict_fraud():
    feature_names = x.columns

    input_data = []
    print("Enter feature values:")
    for feature in feature_names:
        value = input(f"{feature}: ").strip()  # Strip spaces
        try:
            input_data.append(float(value))  # Convert input to float
        except ValueError:
            print(f"Invalid input for {feature}. Please enter a numerical value.")
            return

    # Convert input data to a Pandas DataFrame with the same feature names
    input_df = pd.DataFrame([input_data], columns=feature_names)

    # Apply the same preprocessing steps: scaling and PCA
    input_scaled = scale.transform(input_df)  # Standard scaling
    input_pca = pca.transform(input_scaled)  # PCA transformation

    # Make a prediction using the best model (Decision Tree)
    prediction = models["Decision Tree"].predict(input_pca)
    
    # Display the result
    print("\n\n The claim is likely to be fraudulent." if prediction[0] == 1 else "\n\n The claim is not fraudulent.")

# Call the function to predict fraud
predict_fraud()
# Out:
# Enter feature values:
